# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os 
os.chdir('/content/drive/My Drive/Colab_Notebooks/AdvancedDeepLearningCourse/Session02/ResNet')

# %%
from IPython.display import Image
Image(filename="ResNetArchitecture.PNG")

# %%
Image(filename="ResNetConfiguration.PNG")

# %%
Image(filename="ResidualBlock.PNG")

# %%
import numpy as np

from keras.datasets import cifar10
from keras.utils import to_categorical, plot_model
from keras.layers import Conv2D, Input, Flatten, Dense, Activation, BatchNormalization
from keras.layers import add, AveragePooling2D
from keras.regularizers import l2
from keras.models import Model
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
# Preprocessing

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

pixel_mean = np.mean(x_train, axis=0)

x_train = x_train - pixel_mean
x_test = x_test - pixel_mean

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

print('x_train shape:', x_train.shape)
print('y_train shape:', y_train.shape)

print('x_train shape:', x_test.shape)
print('y_train shape:', y_test.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# y_train shape: (50000, 10)
# x_train shape: (10000, 32, 32, 3)
# y_train shape: (10000, 10)

# %%
n_classes = 10
n = 3
n_stacks = 3
filters = [16, 32, 64]
m_train = x_train.shape[0]

batch_size = 32
epochs = 200

# %%
def resnet_layer(inputs,
                 filters,
                 strides=1,
                 kernel_size=3,
                 activation='relu',
                 batch_normalization=True):
    
    x = Conv2D(filters=filters,
               kernel_size=kernel_size,
               strides=strides,
               padding='same',
               kernel_initializer='he_normal',
               kernel_regularizer=l2(1e-4)
              )(inputs)
    if batch_normalization:
        x = BatchNormalization()(x)
    if activation is not None:
        x = Activation('relu')(x)
    
    return x

# %%
inputs = Input(shape=(32, 32, 3) , name = 'inputs')
x = inputs
x = resnet_layer(inputs= x,
                 filters=16)
print('conv_1:', x.shape)

for stack in range(n_stacks):
    for block in range(n):
        if stack !=0 and block == 0:
            strides = 2
        else:
            strides = 1
        y = resnet_layer(inputs=x,
                         filters=filters[stack],
                         strides=strides)
        y = resnet_layer(inputs=y,
                         filters=filters[stack],
                         activation=None,
                        strides=1)
        if stack !=0 and block == 0:
            x = resnet_layer(inputs=x,
                            filters=filters[stack],
                            kernel_size=1,
                            strides=2,
                            activation=None,
                            batch_normalization=False)
        x = add([x, y])
        x = Activation('relu')(x)
x = AveragePooling2D(8)(x)
x = Flatten()(x)
outputs = Dense(10, activation='softmax',kernel_initializer='he_normal')(x)
# Out:
# conv_1: (?, 32, 32, 16)
# W0821 14:57:52.533811 140368902412160 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.

# %%
model = Model(inputs, outputs, name='resnet_v1_20')
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['acc'])
model.summary()
plot_model(model, 'resnet_v1_20.png', show_shapes=True)
# Out:
# W0821 15:06:49.686794 140368902412160 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 32, 32, 16)   448         inputs[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 32, 32, 16)   64          conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 32, 16)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 32, 32, 16)   2320        activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 32, 32, 16)   64          conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 32, 16)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 32, 32, 16)   2320        activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 32, 32, 16)   64          conv2d_65[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 32, 32, 16)   0           activation_42[0][0]
#                                                                  batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 32, 16)   0           add_27[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 32, 32, 16)   2320        activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 32, 32, 16)   64          conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 32, 16)   0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 32, 32, 16)   2320        activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 32, 32, 16)   64          conv2d_67[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 32, 32, 16)   0           activation_44[0][0]
#                                                                  batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 32, 32, 16)   0           add_28[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 32, 32, 16)   2320        activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 32, 32, 16)   64          conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 32, 32, 16)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 32, 32, 16)   2320        activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 32, 32, 16)   64          conv2d_69[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 32, 32, 16)   0           activation_46[0][0]
#                                                                  batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 32, 32, 16)   0           add_29[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 16, 16, 32)   4640        activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 16, 16, 32)   128         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 16, 16, 32)   0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 16, 16, 32)   9248        activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 16, 16, 32)   544         activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 16, 16, 32)   128         conv2d_71[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 16, 16, 32)   0           conv2d_72[0][0]
#                                                                  batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 16, 16, 32)   0           add_30[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 16, 16, 32)   9248        activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 16, 16, 32)   128         conv2d_73[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 16, 16, 32)   0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 16, 16, 32)   9248        activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 16, 16, 32)   128         conv2d_74[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 16, 16, 32)   0           activation_50[0][0]
#                                                                  batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 16, 16, 32)   0           add_31[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 16, 16, 32)   9248        activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 16, 16, 32)   128         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 16, 16, 32)   0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 16, 16, 32)   9248        activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 16, 16, 32)   128         conv2d_76[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 16, 16, 32)   0           activation_52[0][0]
#                                                                  batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 16, 16, 32)   0           add_32[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 64)     18496       activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 8, 8, 64)     256         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 8, 8, 64)     0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 64)     36928       activation_55[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 64)     2112        activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 8, 8, 64)     256         conv2d_78[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 8, 8, 64)     0           conv2d_79[0][0]
#                                                                  batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 8, 8, 64)     0           add_33[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 64)     36928       activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 8, 8, 64)     256         conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 8, 8, 64)     0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 64)     36928       activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 64)     256         conv2d_81[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 8, 8, 64)     0           activation_56[0][0]
#                                                                  batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 8, 8, 64)     0           add_34[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 64)     36928       activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 64)     256         conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 8, 8, 64)     0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 64)     36928       activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 64)     256         conv2d_83[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 8, 8, 64)     0           activation_58[0][0]
#                                                                  batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 8, 8, 64)     0           add_35[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 64)     0           activation_60[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 64)           0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           650         flatten_1[0][0]
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________

# %%
def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    return lr

# %%
lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)


check_point = ModelCheckpoint(filepath='resnet_v1_20.h5',
                              monitor='val_acc',
                              save_best_only=True,
                              verbose=1)

lr_reducer = ReduceLROnPlateau(monitor='val_loss',
                               patience=5,
                               factor=np.sqrt(0.1),
                               cooldown=0,
                               verbose=1,
                               mean_lr=0.5e-6)

# %%
data_generator = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True)
data_generator.fit(x_train)

# %%
model.fit_generator(data_generator.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=m_train//batch_size,
                    epochs=epochs,
                    validation_data=(x_test, y_test),
                    callbacks=[check_point, lr_scheduler, lr_reducer])
# Out:
# Epoch 1/200
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 107s 69ms/step - loss: 1.6070 - acc: 0.4727 - val_loss: 2.2586 - val_acc: 0.3663
#
# Epoch 00001: val_acc improved from -inf to 0.36630, saving model to resnet_v1_20.h5
# Epoch 2/200
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 101s 65ms/step - loss: 1.2015 - acc: 0.6292 - val_loss: 1.6095 - val_acc: 0.5308
#
# Epoch 00002: val_acc improved from 0.36630 to 0.53080, saving model to resnet_v1_20.h5
# Epoch 3/200
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 99s 63ms/step - loss: 1.0364 - acc: 0.6913 - val_loss: 1.3891 - val_acc: 0.5714
#
# Epoch 00003: val_acc improved from 0.53080 to 0.57140, saving model to resnet_v1_20.h5
# Epoch 4/200
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 99s 63ms/step - loss: 0.9340 - acc: 0.7308 - val_loss: 1.7486 - val_acc: 0.5420
#
# Epoch 00004: val_acc did not improve from 0.57140
# Epoch 5/200
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 97s 62ms/step - loss: 0.8770 - acc: 0.7512 - val_loss: 1.3543 - val_acc: 0.5997
#
# Epoch 00005: val_acc improved from 0.57140 to 0.59970, saving model to resnet_v1_20.h5
# Epoch 6/200
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 92s 59ms/step - loss: 0.8263 - acc: 0.7711 - val_loss: 1.4208 - val_acc: 0.6419
#
# Epoch 00006: val_acc improved from 0.59970 to 0.64190, saving model to resnet_v1_20.h5
# Epoch 7/200
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 96s 61ms/step - loss: 0.7913 - acc: 0.7864 - val_loss: 1.1530 - val_acc: 0.6663
#
# Epoch 00007: val_acc improved from 0.64190 to 0.66630, saving model to resnet_v1_20.h5
# Epoch 8/200
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 95s 61ms/step - loss: 0.7610 - acc: 0.7973 - val_loss: 2.3396 - val_acc: 0.4786
#
# Epoch 00008: val_acc did not improve from 0.66630
# Epoch 9/200
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 96s 62ms/step - loss: 0.7369 - acc: 0.8076 - val_loss: 1.6705 - val_acc: 0.5991
#
# Epoch 00009: val_acc did not improve from 0.66630
# Epoch 10/200
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 97s 62ms/step - loss: 0.7172 - acc: 0.8150 - val_loss: 1.9769 - val_acc: 0.5588
#
# Epoch 00010: val_acc did not improve from 0.66630
# Epoch 11/200
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 96s 61ms/step - loss: 0.7021 - acc: 0.8200 - val_loss: 1.1219 - val_acc: 0.7001
#
# Epoch 00011: val_acc improved from 0.66630 to 0.70010, saving model to resnet_v1_20.h5
# Epoch 12/200
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 97s 62ms/step - loss: 0.6845 - acc: 0.8269 - val_loss: 1.2437 - val_acc: 0.6593
#
# Epoch 00012: val_acc did not improve from 0.70010
# Epoch 13/200
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 96s 62ms/step - loss: 0.6748 - acc: 0.8306 - val_loss: 1.3615 - val_acc: 0.6406
#
# Epoch 00013: val_acc did not improve from 0.70010
# Epoch 14/200
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 95s 61ms/step - loss: 0.6596 - acc: 0.8367 - val_loss: 1.2023 - val_acc: 0.6716
#
# Epoch 00014: val_acc did not improve from 0.70010
# Epoch 15/200
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 96s 61ms/step - loss: 0.6482 - acc: 0.8408 - val_loss: 1.3867 - val_acc: 0.6448
#
# Epoch 00015: val_acc did not improve from 0.70010
# Epoch 16/200
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 94s 60ms/step - loss: 0.6438 - acc: 0.8447 - val_loss: 1.2691 - val_acc: 0.6749
#
# Epoch 00016: val_acc did not improve from 0.70010
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# Epoch 17/200
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 98s 63ms/step - loss: 0.6293 - acc: 0.8494 - val_loss: 1.1778 - val_acc: 0.7054
#
# Epoch 00017: val_acc improved from 0.70010 to 0.70540, saving model to resnet_v1_20.h5
# Epoch 18/200
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 95s 61ms/step - loss: 0.6218 - acc: 0.8502 - val_loss: 1.1195 - val_acc: 0.7076
#
# Epoch 00018: val_acc improved from 0.70540 to 0.70760, saving model to resnet_v1_20.h5
# Epoch 19/200
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 94s 60ms/step - loss: 0.6164 - acc: 0.8542 - val_loss: 1.1063 - val_acc: 0.7207
#
# Epoch 00019: val_acc improved from 0.70760 to 0.72070, saving model to resnet_v1_20.h5
# Epoch 20/200
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 96s 61ms/step - loss: 0.6094 - acc: 0.8566 - val_loss: 1.2297 - val_acc: 0.6899
#
# Epoch 00020: val_acc did not improve from 0.72070
# Epoch 21/200
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 95s 61ms/step - loss: 0.6038 - acc: 0.8595 - val_loss: 0.9983 - val_acc: 0.7459
#
# Epoch 00021: val_acc improved from 0.72070 to 0.74590, saving model to resnet_v1_20.h5
# Epoch 22/200
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 96s 61ms/step - loss: 0.6005 - acc: 0.8601 - val_loss: 1.2684 - val_acc: 0.7004
#
# Epoch 00022: val_acc did not improve from 0.74590
# Epoch 23/200
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 94s 60ms/step - loss: 0.5930 - acc: 0.8643 - val_loss: 1.3169 - val_acc: 0.6645
#
# Epoch 00023: val_acc did not improve from 0.74590
# Epoch 24/200
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 95s 61ms/step - loss: 0.5870 - acc: 0.8663 - val_loss: 0.9734 - val_acc: 0.7523
#
# Epoch 00024: val_acc improved from 0.74590 to 0.75230, saving model to resnet_v1_20.h5
# Epoch 25/200
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 95s 61ms/step - loss: 0.5839 - acc: 0.8662 - val_loss: 1.2302 - val_acc: 0.6902
#
# Epoch 00025: val_acc did not improve from 0.75230
# Epoch 26/200
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 96s 61ms/step - loss: 0.5807 - acc: 0.8684 - val_loss: 1.2457 - val_acc: 0.7006
#
# Epoch 00026: val_acc did not improve from 0.75230
# Epoch 27/200
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 96s 61ms/step - loss: 0.5827 - acc: 0.8677 - val_loss: 0.9725 - val_acc: 0.7557
#
# Epoch 00027: val_acc improved from 0.75230 to 0.75570, saving model to resnet_v1_20.h5
# Epoch 28/200
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 94s 60ms/step - loss: 0.5720 - acc: 0.8717 - val_loss: 1.2753 - val_acc: 0.6840
#
# Epoch 00028: val_acc did not improve from 0.75570
# Epoch 29/200
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 95s 61ms/step - loss: 0.5671 - acc: 0.8734 - val_loss: 1.1471 - val_acc: 0.7149
#
# Epoch 00029: val_acc did not improve from 0.75570
# Epoch 30/200
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 95s 61ms/step - loss: 0.5714 - acc: 0.8737 - val_loss: 1.1977 - val_acc: 0.7078
#
# Epoch 00030: val_acc did not improve from 0.75570
# Epoch 31/200
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 95s 61ms/step - loss: 0.5595 - acc: 0.8748 - val_loss: 0.8529 - val_acc: 0.7784
#
# Epoch 00031: val_acc improved from 0.75570 to 0.77840, saving model to resnet_v1_20.h5
# Epoch 32/200
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 96s 61ms/step - loss: 0.5624 - acc: 0.8753 - val_loss: 0.9360 - val_acc: 0.7654
#
# Epoch 00032: val_acc did not improve from 0.77840
# Epoch 33/200
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 97s 62ms/step - loss: 0.5570 - acc: 0.8784 - val_loss: 1.3475 - val_acc: 0.6790
#
# Epoch 00033: val_acc did not improve from 0.77840
# Epoch 34/200
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 95s 61ms/step - loss: 0.5575 - acc: 0.8778 - val_loss: 1.0765 - val_acc: 0.7372
#
# Epoch 00034: val_acc did not improve from 0.77840
# Epoch 35/200
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 95s 61ms/step - loss: 0.5546 - acc: 0.8789 - val_loss: 1.3735 - val_acc: 0.6666
#
# Epoch 00035: val_acc did not improve from 0.77840
# Epoch 36/200
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 93s 60ms/step - loss: 0.5451 - acc: 0.8816 - val_loss: 1.3977 - val_acc: 0.6735
#
# Epoch 00036: val_acc did not improve from 0.77840
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# Epoch 37/200
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1562/1562 [==============================] - 96s 62ms/step - loss: 0.5496 - acc: 0.8819 - val_loss: 1.1109 - val_acc: 0.7379
#
# Epoch 00037: val_acc did not improve from 0.77840
# Epoch 38/200
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1197/1562 [=====================>........] - ETA: 21s - loss: 0.5407 - acc: 0.8846Buffered data was truncated after reaching the output size limit.
